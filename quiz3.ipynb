# %% [markdown]
# # Quiz 3
#
# **Author:**

# %% [markdown]
# **Exercise 1:**
#
# 1. Import the nobel price data frame using pandas.
#
# 2. Explore the data set:
#
#     2.1. Print the first five rows of the table.
#
#     2.2. Print all the columns in the table.
#
#     2.3. Print the types of all the columns in the table.
#
#     2.4. Would the describe function give us any useful information of this data? (answer based on the data types of the columns).
#
# 3. Select only the gender column. Using a lambda function and the filter function, calculate the number and proportion of woman who have won the nobel price.
#
# 4. Select the column gender and save it in an object called ```g```. Do the same with the column category, and save it in an object called ```c```. Create a new object ```gc = g + c``` and print the content.
#
# 5. Use the object ```gc```, a lambda function and the filter function to calculate the number and proportion of females that have won the economics novel price. Compare that number with the total number of females that have won any nobel price (from question 3)

# %%
import pandas as pd
nobel=pd.read_csv('nobel_prize.csv')

# %%
nobel.head()
# Out:
#    index   id         firstname  surname        born        died bornCountry  \
# 0      0  846            Elinor   Ostrom    8/7/1933   6/12/2012         USA
# 1      1  846            Elinor   Ostrom    8/7/1933   6/12/2012         USA
# 2      2  783      Wangari Muta  Maathai    4/1/1940   9/25/2011       Kenya
# 3      3  230  Dorothy Crowfoot  Hodgkin   5/12/1910   7/29/1994       Egypt
# 4      4  918            Youyou       Tu  12/30/1930  0000-00-00       China
#
#   bornCountryCode         bornCity     diedCountry  ...           diedCity  \
# 0              US  Los Angeles, CA             USA  ...    Bloomington, IN
# 1              US  Los Angeles, CA             USA  ...    Bloomington, IN
# 2              KE            Nyeri           Kenya  ...            Nairobi
# 3              EG            Cairo  United Kingdom  ...  Shipston-on-Stour
# 4              CN  Zhejiang Ningbo             NaN  ...                NaN
#
#    gender    year   category overallMotivation share  \
# 0  female  2009.0  economics               NaN   2.0
# 1  female  2009.0  economics               NaN   2.0
# 2  female  2004.0      peace               NaN   1.0
# 3  female  1964.0  chemistry               NaN   1.0
# 4  female  2015.0   medicine               NaN   2.0
#
#                                           motivation  \
# 0  "for her analysis of economic governance, espe...
# 1  "for her analysis of economic governance, espe...
# 2  "for her contribution to sustainable developme...
# 3  "for her determinations by X-ray techniques of...
# 4  "for her discoveries concerning a novel therap...
#
#                                             name             city  \
# 0                             Indiana University  Bloomington, IN
# 1                       Arizona State University        Tempe, AZ
# 2                                            NaN              NaN
# 3            University of Oxford, Royal Society           Oxford
# 4  China Academy of Traditional Chinese Medicine          Beijing
#
#           country
# 0             USA
# 1             USA
# 2             NaN
# 3  United Kingdom
# 4           China
#
# [5 rows x 21 columns]

# %%
columns = nobel.columns
print(columns)
# Out:
# Index(['index', 'id', 'firstname', 'surname', 'born', 'died', 'bornCountry',
#        'bornCountryCode', 'bornCity', 'diedCountry', 'diedCountryCode',
#        'diedCity', 'gender', 'year', 'category', 'overallMotivation', 'share',
#        'motivation', 'name', 'city', 'country'],
#       dtype='object')

# %%
print(type(columns))
# Out:
# <class 'pandas.core.indexes.base.Index'>

# %%
columns.dtype
# Out:
# dtype('O')

# %%
#2.4. The describe function is used to show the summary statistic. It would give us various kinds of information for the index, id, year, and share. However, this information wouldn't be useful because it is based on quantitative interpretation.

# %%
nobel.describe()
# Out:
#             index          id         year       share
# count  972.000000  972.000000   966.000000  966.000000
# mean   485.500000  471.365226  1970.145963    2.005176
# std    280.736531  275.012711    32.889742    0.930193
# min      0.000000    1.000000  1901.000000    1.000000
# 25%    242.750000  230.750000  1947.000000    1.000000
# 50%    485.500000  463.500000  1976.000000    2.000000
# 75%    728.250000  720.250000  1999.000000    3.000000
# max    971.000000  934.000000  2016.000000    4.000000

# %%
nobel.sort_values(by = 'gender', ascending = True)
# Out:
#      index   id                                          firstname  \
# 0        0  846                                             Elinor
# 27      27  869                                              Ellen
# 28      28  870                                             Leymah
# 29      29  871                                           Tawakkol
# 30      30  914                                             Malala
# ..     ...  ...                                                ...
# 947    947  893  Organisation for the Prohibition of Chemical W...
# 946    946  925                          National Dialogue Quartet
# 970    970  547  International Physicians for the Prevention of...
# 957    957  477  Bureau international permanent de la Paix (Per...
# 971    971  550                 United Nations Peacekeeping Forces
#
#              surname        born        died bornCountry bornCountryCode  \
# 0             Ostrom    8/7/1933   6/12/2012         USA              US
# 27   Johnson Sirleaf  10/29/1938  0000-00-00     Liberia              LR
# 28            Gbowee    2/1/1972  0000-00-00     Liberia              LR
# 29            Karman    2/7/1979  0000-00-00       Yemen              YE
# 30         Yousafzai   7/12/1997  0000-00-00    Pakistan              PK
# ..               ...         ...         ...         ...             ...
# 947              NaN         NaN         NaN         NaN             NaN
# 946              NaN         NaN         NaN         NaN             NaN
# 970              NaN         NaN         NaN         NaN             NaN
# 957              NaN         NaN         NaN         NaN             NaN
# 971              NaN         NaN         NaN         NaN             NaN
#
#             bornCity diedCountry  ...         diedCity  gender    year  \
# 0    Los Angeles, CA         USA  ...  Bloomington, IN  female  2009.0
# 27          Monrovia         NaN  ...              NaN  female  2011.0
# 28          Monrovia         NaN  ...              NaN  female  2011.0
# 29            Ta'izz         NaN  ...              NaN  female  2011.0
# 30           Mingora         NaN  ...              NaN  female  2014.0
# ..               ...         ...  ...              ...     ...     ...
# 947              NaN         NaN  ...              NaN     org  2013.0
# 946              NaN         NaN  ...              NaN     org  2015.0
# 970              NaN         NaN  ...              NaN     org  1985.0
# 957              NaN         NaN  ...              NaN     org  1910.0
# 971              NaN         NaN  ...              NaN     org  1988.0
#
#       category overallMotivation share  \
# 0    economics               NaN   2.0
# 27       peace               NaN   3.0
# 28       peace               NaN   3.0
# 29       peace               NaN   3.0
# 30       peace               NaN   2.0
# ..         ...               ...   ...
# 947      peace               NaN   1.0
# 946      peace               NaN   1.0
# 970      peace               NaN   1.0
# 957      peace               NaN   1.0
# 971      peace               NaN   1.0
#
#                                             motivation                name  \
# 0    "for her analysis of economic governance, espe...  Indiana University
# 27   "for their non-violent struggle for the safety...                 NaN
# 28   "for their non-violent struggle for the safety...                 NaN
# 29   "for their non-violent struggle for the safety...                 NaN
# 30   "for their struggle against the suppression of...                 NaN
# ..                                                 ...                 ...
# 947  "for its extensive efforts to eliminate chemic...                 NaN
# 946  "for its decisive contribution to the building...                 NaN
# 970                                                NaN                 NaN
# 957                                                NaN                 NaN
# 971                                                NaN                 NaN
#
#                 city country
# 0    Bloomington, IN     USA
# 27               NaN     NaN
# 28               NaN     NaN
# 29               NaN     NaN
# 30               NaN     NaN
# ..               ...     ...
# 947              NaN     NaN
# 946              NaN     NaN
# 970              NaN     NaN
# 957              NaN     NaN
# 971              NaN     NaN
#
# [972 rows x 21 columns]

# %%
n = nobel['gender']
b = list(filter(lambda x: x == "female", n))
print(len(b), 'women have won the nobel prize')
# Out:
# 50 women have won the nobel prize

# %%
prop = nobel["gender"]
b = list(filter(lambda x: x== "female", prop))

print(len(nobel))
print(len(b)/len(nobel))

print('The proportion of females to win the nobel prize is:', len(b)/len(nobel))
# Out:
# 972
# 0.051440329218107
# The proportion of females to win the nobel prize is: 0.051440329218107

# %%
g = nobel['gender']
c = nobel['category']
gc = g + c
print(gc)
# Out:
# 0      femaleeconomics
# 1      femaleeconomics
# 2          femalepeace
# 3      femalechemistry
# 4       femalemedicine
#             ...
# 967           orgpeace
# 968           orgpeace
# 969           orgpeace
# 970           orgpeace
# 971           orgpeace
# Length: 972, dtype: object

# %%
i = list(filter(lambda x: x == 'femaleeconomics', gc))
print(len(i), 'women have won the nobel prize in economics from the', len(b), 'women who have won the nobel prize.')
print('The obtained proportion value of this is:', len(i)/len(b))
# Out:
# 2 women have won the nobel prize in economics from the 50 women who have won the nobel prize.
# The obtained proportion value of this is: 0.04
